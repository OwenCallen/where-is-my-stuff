# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten

# %matplotlib inline

# %% [markdown]
# ## EDA

# %%
im1 = Image.open("data/Glasses/glasses135.jpg")
im1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x267 at 0x7F8030447F90>

# %%
np.array(im1).shape
# Out:
# (267, 400, 4)

# %%
plt.imshow(np.array(im1)[:,:,0:3])

# %%
def crop_center(arr, side_length = 150):
    y,x,_ = arr.shape
    startx = x//2 - side_length//2
    endx = x//2 + side_length//2
    
    starty = y//2 - side_length//2
    endy = y//2 + side_length//2
    
    return arr[starty:endy, startx:endx, 0:3]

# %%
file_path = "data/keys/"
names = os.listdir(file_path)

i = 0
for n in names:
    if n != ".DS_Store":
        i+=1
        arr = np.array(Image.open(file_path+n))
        print("________________________________")
        print(n)
        print(arr.shape)
        cropped = crop_center(arr)
        plt.imshow(arr)
        plt.show();
        plt.imshow(cropped)
        plt.show();
        
        if i>= 5:
            break;
        print("dim: ", np.min([arr.shape[0], arr.shape[1]]), np.min([arr.shape[0]/arr.shape[1], arr.shape[1]/arr.shape[0]]))
# Out:
# ________________________________
# 23.jfif
# (189, 267, 3)
# dim:  189 0.7078651685393258
# ________________________________
# 74.jfif
# (158, 212, 3)
# dim:  158 0.7452830188679245
# ________________________________
# 62.jfif
# (194, 259, 3)
# dim:  194 0.749034749034749
# ________________________________
# 9.jfif
# (225, 225, 3)
# dim:  225 1.0
# ________________________________
# 35.jfif
# (225, 225, 3)

# %% [markdown]
# ## Create dataset

# %%
def make_dataset(folders = ["data/keys/", "data/wallets/"]):
    X = []
    y = []
    object_class = 0
    for folder in folders:
        names = os.listdir(folder)
        for n in names:
            if n != ".DS_Store":
                arr = np.array(Image.open(folder+n))
                cropped = crop_center(arr)
                if cropped.shape == (150,150,3):
                    X.append(cropped)
                    y.append(object_class)
        object_class+=1
        
        
    X = np.array(X)
    y = np.array(y)
    y = tf.keras.utils.to_categorical(y, num_classes = object_class)
    
    return X, y

# %%
X, y = make_dataset()
print(X.shape, y.shape)
# Out:
# (256, 150, 150, 3) (256, 2)

# %% [markdown]
# ## neural network (CNN)

# %%
input_nn = Input( shape = (150,150,3) )
x = Conv2D(32, (3,3), activation = "relu")(input_nn)
x = Conv2D(32, (3,3), activation = "relu")(x)
x = MaxPooling2D((2,2))(x)
x = Conv2D(32, (3,3), activation = "relu")(x)
x = Conv2D(32, (3,3), activation = "relu")(x)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dense(32, activation = "relu")(x)
x = Dense(16, activation = "relu")(x)
nn_out = Dense(2, activation='softmax')(x)

nn = Model(input_nn, nn_out)
nn.compile(optimizer='adam', loss='categorical_crossentropy', metrics = [tf.keras.metrics.Accuracy()])
print(nn.summary())

history_nn = nn.fit(X, y, epochs=5,)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 146, 146, 32)      9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 32)        9248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 69, 69, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 32)        0
# ...

# %%
preds = nn.predict(np.float32(X))

# %%
for i in (0,50,100,150,200,250):
    print("__________________")
    print("img: ", i)
    print("label: ", y[i])
    print("prediction: ", np.round(preds[i],3))
    plt.imshow(X[i,:,:,:])
    plt.show();
# Out:
# __________________
# img:  0
# label:  [1. 0.]
# prediction:  [0.945 0.055]
# __________________
# img:  50
# label:  [1. 0.]
# prediction:  [0.637 0.363]
# __________________
# img:  100
# label:  [0. 1.]
# prediction:  [0.049 0.951]
# __________________
# img:  150
# label:  [0. 1.]
# prediction:  [0.444 0.556]
# __________________
# img:  200
# label:  [0. 1.]
# prediction:  [0.042 0.958]
# __________________
# img:  250
# label:  [0. 1.]
# prediction:  [0.111 0.889]
